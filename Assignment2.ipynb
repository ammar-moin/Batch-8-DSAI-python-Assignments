# %%
# Area of a Rectangle:
# Write a Python program to calculate the area of a rectangle. Use the formula:

# Area = length × width

# Take length and width as inputs from the user.

length  = float(input("Enter the length of the Rectangle: "))
width  = float(input("Enter the width of the Rectangle: "))

area = length *width
print(f"Area of the rectangle is: {area}")
# Out:
# Enter the length of the Rectangle: 6
# Enter the width of the Rectangle: 3
# Area of the rectangle is: 18.0

# %%
# Circumference of a Circle:
# Write a Python program to calculate the circumference of a circle. Use the formula:

# Circumference = 2πr

# Take the radius r as input from the user.

radius = float(input("Enter the radius of the circle: "))
circumference = 2*3.142*radius
print(f"The circumference of circle is: {circumference}")
# Out:
# Enter the radius of the circle: 6
# The circumference of circle is: 37.704

# %%
# Simple Interest:
# Write a Python program to calculate the simple interest. Use the formula:
# Simple Interest = Principal × Rate × Time

# Take Principal, Rate, and Time as inputs from the user.

principal = float(input("Enter the Principal: "))
rate = float(input("Enter the Rate: "))
time = float(input("Enter the Time: "))

si = principal * rate* time
print(f"The simple Interest of the given values are: {si}")
# Out:
# Enter the Principal: 5
# Enter the Rate: 3
# Enter the Time: 6
# The simple Interest of the given values are: 90.0

# %%
# Speed of an Object:
# Write a Python program to calculate the speed of an object. Use the formula:
# Speed = Distance / Time

# Take Distance and Time as inputs from the user.
dist = float(input("Distance: "))
time = float(input("Time: "))
speed = dist * time
print(f"The speed of the object is {speed}")
# Out:
# Distance: 49
# Time: 5
# The speed of the object is 245.0

# %%
# 5) BMI Calculator:
# Write a Python program to calculate the Body Mass Index (BMI). Use the formula:


# Take Weight (in kilograms) and Height (in meters) as inputs from the user.

weight = float(input("Enter the weight in kilogram: "))
height = float(input("Enter Height in meters: "))
bmi = weight // (height**2)
print(f"Body Mass Index BMI is: {bmi}")
# Out:
# Enter the weight in kilogram: 49
# Enter Height in meters: 5
# Body Mass Index BMI is: 1.0

# %%
# Force Using Newton's Second Law:

# Write a Python program to calculate the force on an object. Use the formula:

# Take m (mass in kilograms) and a (acceleration in meters/second2) as inputs from the
# user.
m = float(input("Enter mass in kilogram: "))
a = float(input("Enter acceleration is (m/s^2): "))
force = m*a
print(f"Force on an object is: {force} newton")
# Out:
# Enter mass in kilogram: 49
# Enter acceleration is (m/s^2): 10
# Force on an object is: 490.0

# %%
# 7) Compound Interest:
# Write a Python program to calculate compound interest. Use the formula:



# Where:
# A= total amount
# P = principal amount
# r = annual interest rate (decimal)
# n = number of times interest is compounded per year
# t = time in years
# Take P, r, n, and t as inputs from the user.


p = float(input("Enter principal amount: "))
r = int(input("Annual interest rate: "))
n = int(input("number of times interest is compounded per year: "))
t = int(input("time in years: "))

a = p * (1 + r/n)**(n-t)
print(f"Total amount is: {a}")
# Out:
# Enter principal amount: 30
# Annual interest rate: 5
# number of times interest is compounded per year: 7
# time in years: 4
# Total amount is: 151.1370262390671

# %%
# 8) Perimeter of a Triangle:
# Write a Python program to calculate the perimeter of a triangle. Use the formula:

# Perimeter = a + b + c

# Take a, b, and c (lengths of the three sides) as inputs from the user.

a = float(input("Length of side a: "))
b = float(input("Length of side b: "))
c = float(input("Length of side c: "))
perimeter = a+b+c
print(f"The perimeter of triangle is: {perimeter}")
# Out:
# Length of side a: 5
# Length of side b: 3
# Length of side c: 6
# The perimeter of triangle is: 14.0

# %%
# 9) Volume of a Sphere:
# Write a Python program to calculate the volume of a sphere. Use the formula:



# Take r (radius) as input from the user.

r = float(input("Enter the radius of the sphere: "))
volume = 4/3 * 3.142 * (r**3)
print(f"THe volume of the sphere is: {volume}")
# Out:
# Enter the radius of the sphere: 7
# THe volume of the sphere is: 1436.9413333333332

# %%
# Kinetic Energy:
# Write a Python program to calculate the kinetic energy of an object. Use the formula:



# Take m (mass in kilograms) and v (velocity in meters/second) as inputs from the user.
m = float(input("Enter the mass in kilogram: "))
v = float(input("Enter the velocity in m/s: "))
ke = 1/2 * (m*v**2)
print(f"The Kinetic Energy of an object is: {ke}")
# Out:
# Enter the mass in kilogram: 60
# Enter the velocity in m/s: 80
# The Kinetic Energy of an object is: 192000.0

# %%
# 11) Quadratic Equation Roots:
# Write a Python program to find the roots of a quadratic equation. Use the formula:

# Take a, b, and c as inputs from the user.



a = float(input("Enter coeffient a: "))
b = float(input("Enter coeffient b: "))
c = float(input("Enter coeffient c: "))

if a== 0:
  print("This is not a quadratic equation. 'a' must not be zero.")
else:

  discriminant = b**2 - 4*a*c

  if discriminant > 0:
    root1 = (-b +(discriminant**0.5)) / (2*a)
    root1 = (-b -(discriminant**0.5)) / (2*a)
    print(f"The roots of quadratic equation are: {root1} and {root2} (Real and distinct)")

  elif discriminant == 0:
    root = -b/(2*a)
    print(f"The root of the quadratic equation is: {root} (Real & Equal)")
  else:
    real_part = -b /(2*a)
    imaginary_part = ((-discriminant)**0.5) / (2*a)
    print(f"The roots of the quadratic equation are: {real_part} + {round(imaginary_part,2)}i and {real_part} - {round(imaginary_part,2)}i (Complex roots)")
# Out:
# Enter coeffient a: 2
# Enter coeffient b: 4
# Enter coeffient c: 6
# The roots of the quadratic equation are: -1.0 + 1.41i and -1.0 - 1.41i (Complex roots)

# %%
# Temperature Conversion:
# • Write a Python program to convert a temperature from Celsius to Fahrenheit. Use the
# formula: ### F= 9/5 C+32

# take c (temp in celsius) as input from the user.

c = float(input("Enter the temperature in Celsius: "))
f = (9/5)* c +32
print(f"The temperature in Fahrenheit is: {f:.2f}°F")
# Out:
# Enter the temperature in Celsius: 43.5
# The temperature in Fahrenheit is: 110.30°F

# %%
# 14) Volume of a Cylinder:
# • Write a Python program to calculate the volume of a cylinder. Use the formula: ###
# Volume = πr2h
# • Take radius(r) and height(h) as inputs from the user

r = float(input("Enter the radius of the cylinder (in meters): "))
h = float(input("Enter the height of the Cylinder (in meters): "))
volume = 3.1426*(r**2)*h
print(f"The volume of the cylinder is: {volume:.2f} cubic meters")

# %%
# 15) Pressure:
# • Write a Python program to calculate the pressure exerted by a force on a surface. Use the
# formula: ### P = F/A
# • P = pressure
# • F = force
# • A = area
# • Take F(force) and A(area) as inputs from the user.

f = float(input("Enter the force (in Newtons): "))
a = float(input("Enter the area (in Sq.Meters): "))
p = round(f/a,2)
print(f"The pressure exert is: {p} pascals(Pa)")

# %%
# 16) Electric Power:
# • Write a Python program to calculate the electric power consumed. Use the formula: ###
# P= V/I
# • where:
# • P = power
# • V = voltage
# • I = current
# • Take V(voltage) and I(current) as inputs from the user.

v = float(input("Enter the voltage (in volt): "))
i = float(input("Enter the current (in Amperes): "))
p = round(v/i)
print(f"The electric power cosumed is: {p} watts")

# %%
# 17) Perimeter of a Circle (Circumference):
# • Write a Python program to calculate the perimeter (circumference) of a circle. Use the
# formula: ### P=2πr
# take radius as input from user

r = float(input("Enter the radius of the circle (in meters): "))
perimeter = round(2*3.1426*r,2)
print(f"The perimeter of circle is {perimeter} meters")

# %%
# 18) Future Value in Savings:
# • Write a Python program to calculate the future value of an investment. Use the formula:
# ### FV = PV(1 + r)^t
# • where:
# – FV= future value
# – PV= present value
# – r= annual interest rate (as a decimal)
# – t= time in years
# • Take PV, r, and t as inputs from the user.
pv = float(input("Enter the present Value (initial investment): "))
r = float(input("Enter the annual interest rate (in decimal): "))
t = float(input("Enter the time  in years: "))
fv = round(pv*(1+r)**t,2)
print(f"The future value of the investment is : {fv}")

# %%
# 19) Work Done by a Force:
# • Write a Python program to calculate the work done by a force. Use the formula:
# • where:
# – W = work done
# – f= force
# – d = distance
# – theta = angle between force and direction of movement (in degrees)
# • Take f, d, and as inputs from the user.
import math
f = float(input("Enter the force applied (in Newtons): "))
d = float(input("Enter the distance moved (in meters): "))
theta = float(input("Enter the angle (in degree) b/w force & distance direction: "))
rad_theta = math.radians(theta)
w = round(f*d*math.cos(rad_theta),2)
print(f"The work done by the force is: {w} Joules.")

# %%
# 20) Heat Transfer:
# • Write a Python program to calculate the amount of heat transferred. Use the formula:
# ### Q = mc (∆T)
# • where:
# – Q= heat transfer
# – m = mass
# – c = specific heat capacity
# – ΔT
# • Take m, c, T as inputs from the user.

m = float(input("Enter the mass (in kg): "))
c = float(input("Enter the specific heat Capacity (in J/kg°C): "))
t = float(input("Enter the temperature change (in °C): "))
q = m*c*t
print(f"THe amount of heat transferred is: {q} Joules.")
# Out:
# Enter the mass (in kg): 5
# Enter the specific heat Capacity (in J/kg°C): 0.5
# Enter the temperature change (in °C): 20
# THe amount of heat transferred is: 50.0 Joules.
