# %% [markdown]
# # Strings Assignments
#
# 1. Write a program that accepts a string from user. Your program should count and display number of
# vowels in that string.

# %%
user_input = input("Enter a string: ")

vowel_count = 0
vowels = "aeiouAEIOU"

for char in user_input:
  if char in vowels:
    vowel_count +=1

print(f"The number of vowels in the strings is: {vowel_count}")
# Out:
# Enter a string: alexandar
# The number of vowels in the strings is: 4

# %% [markdown]
# 2. Write a program that reads a string from keyboard and display:
# * The number of uppercase letters in the string
# * The number of lowercase letters in the string
# * The number of digits in the string
# * The number of whitespace characters in the string

# %%
user_input = input("Enter a strings: ")

uppercase_count = 0
lowercase_count = 0
digit_count = 0
whitespace_count = 0

for char in user_input:
  if char.isupper():
    uppercase_count += 1
  elif char.islower():
    lowercase_count +=1
  elif char.isdigit():
    digit_count +=1
  elif char.isspace():
    whitespace_count +=1

print(f"""Number of uppercase letters: {uppercase_count}
Number of lowercase letters: {lowercase_count}
Number of digits: {digit_count}
Number of whitespace characters: {whitespace_count}

""",)
# Out:
# Enter a strings: Hey! How Are You Doing.
# Number of uppercase letters: 5
# Number of lowercase letters: 12
# Number of digits: 0
# Number of whitespace characters: 4

# %% [markdown]
# 3. Write a Python program that accepts a string from user. Your program should create and display a
# new string where the first and last characters have been exchanged.

# %%
user_input = input("Enter a string: ")

if len(user_input) >=2:
  newString = user_input[-1] + user_input[1:-1]+ user_input[0]
else:
  newString = user_input

print(f"The new string is: {newString}")
# Out:
# Enter a string: Hello
# The new string is: oellH

# %% [markdown]
# 4. Write a Python program that accepts a string from user. Your program should create a new string in
# reverse of first string and display it.

# %%
user_input = input("Enter a string: ")

reversed_string = user_input[::-1]
print(f"The reversed of ther user string is: {reversed_string}")
# Out:
# Enter a string: EXAM
# The reversed of ther user string is: MAXE

# %% [markdown]
# Write a Python program that accepts a string from user. Your program should create a new string by
# shifting one position to left.

# %%
user_input = input("Enter a string: ")

if len(user_input) > 0:
  shiftedString = user_input[1:] +user_input[0]
else:
  shiftedString = user_input

print(f"The new string after shifting one position to the left is: {shiftedString}")
# Out:
# Enter a string: examination 2021
# The new string after shifting one position to the left is: xamination 2021e

# %% [markdown]
# 6. Write a program that asks the user to input his name and print its initials. Assuming that the user
# always types first name, middle name and last name and does not include any unnecessary spaces.

# %%
userName = input("Enter your name: ")

initials = ""
i = 0

while i<len(userName):
  if i == 0 or userName[i-1] == " ":
    initials += userName[i]+ ". "
  i+=1

print(f"The Initials of your name are: {initials}")
# Out:
# Enter your name: Ajay Kumar Garg
# The Initials of your name are: A. K. G.

# %% [markdown]
# 7. A palindrome is a string that reads the same backward as forward. For example, the words dad,
# madam and radar are all palindromes. Write a programs that determines whether the string is a
# palindrome.
# Note: do not use reverse() method

# %%
user_input = input("Enter a string: ").lower()

left = 0
right = len(user_input) -1

is_palindrome = True

while left < right:
  if user_input[left] != user_input[right]:
    is_palindrome = False
    break
  left +=1
  right -=1


if is_palindrome:
  print("The string is a palindrome.")
else:
  print("The string is not a palindrime.")
# Out:
# Enter a string: level
# The string is a palindrome.

# %% [markdown]
# 8. Write a program that display following output:
# SHIFT
# HIFTS
# IFTSH
# FTSHI
# TSHIF
# SHIFT

# %%
s = input("Enter a string: ")
for i in range(len(s)+1):
  print(s)
  s = s[1:]+s[0]
# Out:
# Enter a string: shift
# shift
# hifts
# iftsh
# ftshi
# tshif
# shift

# %% [markdown]
# 9. Write a program in python that accepts a string to setup a passwords. Your entered password must
# meet the following requirements:
#
# The password must be at least eight characters long.
# It must contain at least one uppercase letter.
# It must contain at least one lowercase letter.
# It must contain at least one numeric digit.
# Your program should should perform this validation.

# %%
from re import T
password = input("Enter a password: ")

is_valid = True
has_upper= False
has_lower =False
has_digit = False

if len(password) < 8:
  print("Error: Password must be at least 8 characters long.")
  is_valid = False

for char in password:
  if char.isupper():
    has_upper = True
  if char.islower():
    has_lower = True
  if char.isdigit():
    has_digit = True

if is_valid and has_upper and has_lower and has_digit:
  print("Password is valid.")
else:
  print("""Password is in valid.
The password must be at least eight characters long.
It must contain at least one uppercase letter.
It must contain at least one lowercase letter.
It must contain at least one numeric digit.
   """)
# Out:
# Enter a password: Admin2025
# Password is valid.
